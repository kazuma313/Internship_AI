# %%
# !pip install bert
# Out:
# Requirement already satisfied: bert in /usr/local/lib/python3.10/dist-packages (2.2.0)
# Requirement already satisfied: erlastic in /usr/local/lib/python3.10/dist-packages (from bert) (2.0.0)

# %%
# !pip install bert-tensorflow
# Out:
# Requirement already satisfied: bert-tensorflow in /usr/local/lib/python3.10/dist-packages (1.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from bert-tensorflow) (1.16.0)

# %%
bert_model_hub = "https://tfhub.dev/google/bert_uncased_L-12_H-768_A-12/1"

# %%
import os
import collections
import pandas as pd
import tensorflow as tf
import tensorflow_hub as hub
from datetime import datetime

# %%
import bert
# from bert import run_classifier
from bert import optimization
from bert import tokenization
from bert import modeling
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-e94dff7b7765> in <cell line: 5>()
#       3 from bert import optimization
#       4 from bert import tokenization
# ----> 5 from bert import modeling
#
# /usr/local/lib/python3.10/dist-packages/bert/modeling.py in <module>
#      27 import six
#      28 import tensorflow.compat.v1 as tf
# ---> 29 from tensorflow.contrib import layers as contrib_layers
#      30
#      31
#
# ModuleNotFoundError: No module named 'tensorflow.contrib'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
bert_module = hub.Module(
    "https://tfhub.dev/google/bert_uncased_L-12_H-768_A-12/1")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-54d95d13dedc> in <cell line: 1>()
# ----> 1 bert_module = hub.Module(
#       2     "https://tfhub.dev/google/bert_uncased_L-12_H-768_A-12/1")
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_hub/module.py in __init__(self, spec, trainable, name, tags)
#     163       raise ValueError("No such graph variant: tags=%r" % tags)
#     164
# --> 165     abs_state_scope = _try_get_state_scope(name, mark_name_scope_used=False)
#     166     self._name = abs_state_scope.split("/")[-2]
#     167
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_hub/module.py in _try_get_state_scope(name, mark_name_scope_used)
#     399     unique_name_scope = graph.unique_name(name, mark_name_scope_used) + "/"
#     400     if unique_name_scope != abs_state_scope:
# --> 401       raise RuntimeError(
#     402           "variable_scope %s was unused but the corresponding "
#     403           "name_scope was already taken." % abs_state_scope)
#
# RuntimeError: variable_scope module_1/ was unused but the corresponding name_scope was already taken.
