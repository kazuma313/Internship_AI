# %%
# !pip install -U bertopic
# !pip install -U safetensors
# !pip install Sastrawi
# !pip install openAi
# Out:
# Collecting bertopic
#   Downloading bertopic-0.15.0-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.23.5)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 15.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 14.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.1)
# Collecting sentence-transformers>=0.4.1 (from bertopic)
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.15.0)
# Requirement already satisfied: cython<3,>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.36)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.10.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (23.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.2.0)
# Collecting transformers<5.0.0,>=4.6.0 (from sentence-transformers>=0.4.1->bertopic)
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 48.2 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.15.2+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Collecting sentencepiece (from sentence-transformers>=0.4.1->bertopic)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.8 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers>=0.4.1->bertopic)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.5 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 59.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.7.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2023.6.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 58.2 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading safetensors-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.8 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039161 sha256=7e44f7a377a18ddc6a02bb2ffa9ae08ea10a07aa99a9cc19f739aaae9b5744f0
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125924 sha256=c530cef8db14a8522f2652b57b20c91be5851ee3f2e443a44e14774f77352f65
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82808 sha256=299fc95b1fa721658a7c5e851ebcab77cc8e11385c95e1973a61174e1ceebea4
#   Stored in directory: /root/.cache/pip/wheels/a0/e8/c6/a37ea663620bd5200ea1ba0907ab3c217042c1d035ef606acc
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55617 sha256=fefd2285c772561d2a29fc5160ab00f1b8cf793dab9dc06213e566573e49e4aa
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: tokenizers, sentencepiece, safetensors, huggingface-hub, transformers, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
# Successfully installed bertopic-0.15.0 hdbscan-0.8.33 huggingface-hub-0.16.4 pynndescent-0.5.10 safetensors-0.3.2 sentence-transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.31.0 umap-learn-0.5.3
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (0.3.2)
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
# Collecting openAi
#   Downloading openai-0.27.8-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openAi) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openAi) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openAi) (3.8.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openAi) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openAi) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openAi) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openAi) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openAi) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openAi) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openAi) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openAi) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openAi) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openAi) (1.3.1)
# Installing collected packages: openAi
# Successfully installed openAi-0.27.8

# %%
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

import nltk
nltk.download('stopwords')

from bertopic import BERTopic

import pandas as pd
# from cuml.manifold import UMAP
# from cuml.cluster import HDBSCAN
import umap
import hdbscan

from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.representation import PartOfSpeech, KeyBERTInspired, MaximalMarginalRelevance, OpenAI

# Load model directly
from transformers import pipeline

# Prepare sub-models
from sentence_transformers import SentenceTransformer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from sklearn import preprocessing
encoder = preprocessing.LabelEncoder()
import tensorflow as tf

# %%
df_ekonomi = pd.read_csv('ekonomi.csv')
df_gayaHidup = pd.read_csv('gayaHidup.csv')
df_hiburan = pd.read_csv('hiburan.csv')
df_hukumKriminal = pd.read_csv('hukumKriminal.csv')
df_internasional = pd.read_csv('internasional.csv')
df_keamanan = pd.read_csv('keamanan.csv')
df_olahraga = pd.read_csv('olahraga.csv')
df_ototmotif = pd.read_csv('otomtif.csv')
df_politik = pd.read_csv('politik.csv')
df_teknologi = pd.read_csv('teknolog.csv')

df_ekonomi['label'] = 'Ekonomi'
df_gayaHidup['label'] = 'GayaHidup'
df_hiburan['label'] = 'Hiburan'
df_hukumKriminal['label'] = 'HukumKrimnial'
df_internasional['label'] = 'Internasional'
df_keamanan['label'] = 'Keamanan'
df_olahraga['label'] = 'Olahraga'
df_ototmotif['label'] = 'Otomotif'
df_politik['label'] = 'Politik'
df_teknologi['label'] = 'Teknologi'
print("ekonomi",df_ekonomi.shape)
print("gaya Hidup",df_gayaHidup.shape)
print("hiburan",df_hiburan.shape)
print("hukum Kriminal",df_hukumKriminal.shape)
print("internasional",df_internasional.shape)
print("keamanan",df_keamanan.shape)
print("olahraga",df_olahraga.shape)
print("otomotif",df_ototmotif.shape)
print("politik",df_politik.shape)
print("teknologi",df_teknologi.shape)
df_ekonomi, df_Test_ekonomi = df_ekonomi.iloc[:400, :], df_ekonomi.iloc[400:, :]
df_gayaHidup, df_Test_gayaHidup = df_gayaHidup.iloc[:400, :], df_gayaHidup.iloc[400:, :]
df_hiburan, df_Test_hiburan = df_hiburan.iloc[:400, :], df_hiburan.iloc[400:, :]
df_hukumKriminal, df_Test_hukumKriminal = df_hukumKriminal.iloc[:400, :], df_hukumKriminal.iloc[400:, :]
df_internasional, df_Test_internasional = df_internasional.iloc[:400, :], df_internasional.iloc[400:, :]
df_keamanan, df_Test_keamanan = df_keamanan.iloc[:400, :], df_keamanan.iloc[400:, :]
df_olahraga, df_Test_olahraga = df_olahraga.iloc[:400, :], df_olahraga.iloc[400:, :]
df_ototmotif, df_Test_ototmotif = df_ototmotif.iloc[:400, :], df_ototmotif.iloc[400:, :]
df_politik, df_Test_politik = df_politik.iloc[:400, :], df_politik.iloc[400:, :]
df_teknologi, df_Test_teknologi = df_teknologi.iloc[:400, :], df_teknologi.iloc[400:, :]
print("train ekonomi",df_ekonomi.shape)
print("train gaya Hidup",df_gayaHidup.shape)
print("train hiburan",df_hiburan.shape)
print("train hukum Kriminal",df_hukumKriminal.shape)
print("train internasional",df_internasional.shape)
print("train keamanan",df_keamanan.shape)
print("train olahraga",df_olahraga.shape)
print("train otomotif",df_ototmotif.shape)
print("train politik",df_politik.shape)
print("train teknologi",df_teknologi.shape)
df_train  = pd.concat([df_ekonomi,df_gayaHidup,df_hiburan,df_hukumKriminal,df_internasional,df_keamanan,df_olahraga,df_ototmotif,df_politik,df_teknologi])
df_test = pd.concat([df_Test_ekonomi,df_Test_gayaHidup,df_Test_hiburan,df_Test_hukumKriminal,df_Test_internasional,df_Test_keamanan,df_Test_olahraga,df_Test_ototmotif,df_Test_politik,df_Test_teknologi])
df_train = df_train.sample(frac =1).reset_index(drop = True)
df_test = df_test.sample(frac = 1).reset_index(drop = True)
df_train.drop(columns = ["Unnamed: 0"], inplace = True)
df_test.drop(columns = "Unnamed: 0", inplace = True)
# Out:
# ekonomi (490, 3)
# gaya Hidup (490, 3)
# hiburan (490, 3)
# hukum Kriminal (490, 3)
# internasional (490, 3)
# keamanan (643, 3)
# olahraga (490, 3)
# otomotif (490, 3)
# politik (490, 3)
# teknologi (490, 3)
# train ekonomi (400, 3)
# train gaya Hidup (400, 3)
# train hiburan (400, 3)
# train hukum Kriminal (400, 3)
# train internasional (400, 3)
# train keamanan (400, 3)
# train olahraga (400, 3)
# train otomotif (400, 3)
# train politik (400, 3)
# train teknologi (400, 3)

# %%
def prerocessing_indo(sentences):
    # case Folding
    sentences = [sentence.lower() for sentence in sentences]

    # tokenizer
    tokenizer     = RegexpTokenizer(r'(?<!\S)[A-Za-z]+(?!\S)|(?<!\S)[A-Za-z]+(?=:(?!\S))')
    # hasil_token   = tokenizer.tokenize(sentences[1])
    token_sentence = [tokenizer.tokenize(sentence) for sentence in sentences]

    # stopword
    # wordlist= set(stopwords.words('indonesian')+["all", "halaman", "off", "mengunggah file"]+ stopwords.words('english'))
    # sw_sentences = [[word for word in sentence if word not in wordlist]for sentence in token_sentence]
    cleaned_sentences = [' '.join(sentence) for sentence in token_sentence]

    sentence = cleaned_sentences
    return sentence

# %%
X_train = df_train.iloc[:, -2].values.tolist()
y_train = df_train.iloc[:, -1].values.tolist()

# X_test = df_test.iloc[:, -2].values.tolist()
# y_test = df_test.iloc[:, -1].values.tolist()

# %%
doc = prerocessing_indo(X_train)

# %%
len(doc)
# Out:
# 4000

# %%
len(y_train)
# Out:
# 4000

# %%
import numpy as np

# %%
# from sklearn import preprocessing
# encoder = preprocessing.LabelEncoder()

# %%
# encoder.fit(y_train)

# %%
# y_train = encoder.transform(y_train)
# file:///Users/developeroptimasi/Documents/Zulda/download/BertTopic/model_umap_%7B'n_components'_%202,%20'n_neighbors'_%2030,%20'metric'_%20'cosine',%20'verbose'_%20True,%20'min_dist'_%200.1%7D_hdbscan_%7B'min_samples'_%2040,%20'gen_min_span_tree'_%20True,%20'prediction_data'_%20True,%20'min_cluster_size'_%2040%7D.html

# %%
umap_parameters = [
                  # {"n_components":2, "n_neighbors":30, "metric":"cosine", "verbose" : True, 'min_dist': 0.1}, banyak sekali topik, lebih sedikit topik
                  # {"n_components":2, "n_neighbors":20, "metric":"cosine", "verbose" : True, 'min_dist': 0.01}, 18 topik
                  # {"n_components":2, "n_neighbors":10, "metric":"cosine", "verbose" : True, 'min_dist': 0.001},
                  # {"n_components":2, "n_neighbors":2, "metric":"cosine", "verbose" : True, 'min_dist': 0.001} sedikit topik
                  ]

hdbscan_parameters = [
      {"min_samples":60, "gen_min_span_tree":True, 'prediction_data':True, "min_cluster_size":60},
      # {"min_samples":40, "gen_min_span_tree":True, 'prediction_data':True, "min_cluster_size":40},lebih seikit topik
      # {"min_samples":20, "gen_min_span_tree":True, 'prediction_data':True, "min_cluster_size":20},
      {"min_samples":5, "gen_min_span_tree":True, 'prediction_data':True, "min_cluster_size":5}
]

# %%
vectorizer_model = CountVectorizer(stop_words=stopwords.words('indonesian')+["all", "halaman", "off"] + stopwords.words('english'), ngram_range=(1, 2))
embedding_model = SentenceTransformer('firqaaa/indo-sentence-bert-base')

# %%
pretrained_name = "w11wo/indonesian-roberta-base-posp-tagger"

POS_indo = pipeline(
    "token-classification",
    model=pretrained_name,
    tokenizer=pretrained_name
)

# %%
for umap_param in umap_parameters:
  for hdbscan_param in hdbscan_parameters:
    umap_model = umap.UMAP(**umap_param)
    hdbscan_model = hdbscan.HDBSCAN(**hdbscan_param)

    representation_models = {
    "POS": POS_indo,
    "KeyBERTInspired": KeyBERTInspired(),
    "MMR": MaximalMarginalRelevance(diversity=0.3),
    "KeyBERT + MMR": [KeyBERTInspired(), MaximalMarginalRelevance(diversity=0.3)],
    # "OpenAI_Label": OpenAI(model="gpt-3.5-turbo", exponential_backoff=True, chat=True, diversity=0.1),
    # "OpenAI_Summary": [KeyBERTInspired(), summarization_model],
    }

    # docs
    # Fit BERTopic
    topic_model= BERTopic(
            embedding_model=embedding_model,
            umap_model=umap_model,
            hdbscan_model=hdbscan_model,
            vectorizer_model=vectorizer_model,
            representation_model=representation_models,
            # verbose=True
    )

    topics, probs = topic_model.fit_transform(doc)
     # Visualize the hierarchy and save the figure to an HTML file
    fig = topic_model.visualize_hierarchy()
    fig.write_html(f'model_umap_{umap_param}_hdbscan_{hdbscan_param}.html')
# Out:
# UMAP(angular_rp_forest=True, metric='cosine', n_neighbors=30, verbose=True)
# Mon Aug 21 03:41:25 2023 Construct fuzzy simplicial set
# Mon Aug 21 03:41:49 2023 Finding Nearest Neighbors
# Mon Aug 21 03:41:50 2023 Finished Nearest Neighbor Search
# Mon Aug 21 03:41:50 2023 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Mon Aug 21 03:42:00 2023 Finished embedding
# UMAP(angular_rp_forest=True, metric='cosine', n_neighbors=30, verbose=True)
# Mon Aug 21 03:45:28 2023 Construct fuzzy simplicial set
# Mon Aug 21 03:45:50 2023 Finding Nearest Neighbors
# Mon Aug 21 03:45:51 2023 Finished Nearest Neighbor Search
# Mon Aug 21 03:45:51 2023 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Mon Aug 21 03:46:02 2023 Finished embedding
# UMAP(angular_rp_forest=True, metric='cosine', n_neighbors=30, verbose=True)
# Mon Aug 21 03:50:13 2023 Construct fuzzy simplicial set
# Mon Aug 21 03:50:37 2023 Finding Nearest Neighbors
# Mon Aug 21 03:50:38 2023 Finished Nearest Neighbor Search
# Mon Aug 21 03:50:38 2023 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Mon Aug 21 03:50:48 2023 Finished embedding
# UMAP(angular_rp_forest=True, metric='cosine', n_neighbors=30, verbose=True)
# Mon Aug 21 03:57:00 2023 Construct fuzzy simplicial set
# Mon Aug 21 03:57:22 2023 Finding Nearest Neighbors
# Mon Aug 21 03:57:23 2023 Finished Nearest Neighbor Search
# Mon Aug 21 03:57:23 2023 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Mon Aug 21 03:57:34 2023 Finished embedding
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0.01, n_neighbors=20, verbose=True)
# Mon Aug 21 04:13:24 2023 Construct fuzzy simplicial set
# Mon Aug 21 04:13:46 2023 Finding Nearest Neighbors
# Mon Aug 21 04:13:47 2023 Finished Nearest Neighbor Search
# Mon Aug 21 04:13:47 2023 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Mon Aug 21 04:13:58 2023 Finished embedding
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0.01, n_neighbors=20, verbose=True)
# Mon Aug 21 04:17:30 2023 Construct fuzzy simplicial set
# Mon Aug 21 04:17:57 2023 Finding Nearest Neighbors
# Mon Aug 21 04:17:57 2023 Finished Nearest Neighbor Search
# Mon Aug 21 04:17:58 2023 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Mon Aug 21 04:18:09 2023 Finished embedding
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0.01, n_neighbors=20, verbose=True)
# Mon Aug 21 04:22:57 2023 Construct fuzzy simplicial set
# Mon Aug 21 04:23:22 2023 Finding Nearest Neighbors
# Mon Aug 21 04:23:23 2023 Finished Nearest Neighbor Search
# Mon Aug 21 04:23:23 2023 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Mon Aug 21 04:23:34 2023 Finished embedding
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0.01, n_neighbors=20, verbose=True)
# Mon Aug 21 04:31:12 2023 Construct fuzzy simplicial set
# Mon Aug 21 04:31:34 2023 Finding Nearest Neighbors
# Mon Aug 21 04:31:35 2023 Finished Nearest Neighbor Search
# Mon Aug 21 04:31:35 2023 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Mon Aug 21 04:31:46 2023 Finished embedding
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0.001, n_neighbors=10, verbose=True)
# Mon Aug 21 04:48:10 2023 Construct fuzzy simplicial set
# Mon Aug 21 04:48:34 2023 Finding Nearest Neighbors
# Mon Aug 21 04:48:35 2023 Finished Nearest Neighbor Search
# Mon Aug 21 04:48:35 2023 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Mon Aug 21 04:48:43 2023 Finished embedding
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0.001, n_neighbors=10, verbose=True)
# Mon Aug 21 04:52:17 2023 Construct fuzzy simplicial set
# Mon Aug 21 04:52:41 2023 Finding Nearest Neighbors
# Mon Aug 21 04:52:42 2023 Finished Nearest Neighbor Search
# Mon Aug 21 04:52:42 2023 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Mon Aug 21 04:52:49 2023 Finished embedding
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0.001, n_neighbors=10, verbose=True)
# Mon Aug 21 04:56:33 2023 Construct fuzzy simplicial set
# Mon Aug 21 04:56:57 2023 Finding Nearest Neighbors
# Mon Aug 21 04:56:58 2023 Finished Nearest Neighbor Search
# Mon Aug 21 04:56:58 2023 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Mon Aug 21 04:57:04 2023 Finished embedding
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0.001, n_neighbors=10, verbose=True)
# Mon Aug 21 05:05:06 2023 Construct fuzzy simplicial set
# Mon Aug 21 05:05:30 2023 Finding Nearest Neighbors
# Mon Aug 21 05:05:31 2023 Finished Nearest Neighbor Search
# Mon Aug 21 05:05:31 2023 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Mon Aug 21 05:05:39 2023 Finished embedding
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0.001, n_neighbors=2, verbose=True)
# Mon Aug 21 05:25:01 2023 Construct fuzzy simplicial set
# Mon Aug 21 05:25:24 2023 Finding Nearest Neighbors
# Mon Aug 21 05:25:25 2023 Finished Nearest Neighbor Search
# Mon Aug 21 05:25:25 2023 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Mon Aug 21 05:25:33 2023 Finished embedding
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0.001, n_neighbors=2, verbose=True)
# Mon Aug 21 05:28:59 2023 Construct fuzzy simplicial set
# Mon Aug 21 05:29:23 2023 Finding Nearest Neighbors
# Mon Aug 21 05:29:24 2023 Finished Nearest Neighbor Search
# Mon Aug 21 05:29:24 2023 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Mon Aug 21 05:29:30 2023 Finished embedding
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0.001, n_neighbors=2, verbose=True)
# Mon Aug 21 05:32:56 2023 Construct fuzzy simplicial set
# Mon Aug 21 05:33:20 2023 Finding Nearest Neighbors
# Mon Aug 21 05:33:21 2023 Finished Nearest Neighbor Search
# Mon Aug 21 05:33:21 2023 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Mon Aug 21 05:33:28 2023 Finished embedding
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0.001, n_neighbors=2, verbose=True)
# Mon Aug 21 05:37:22 2023 Construct fuzzy simplicial set
# Mon Aug 21 05:37:46 2023 Finding Nearest Neighbors
# Mon Aug 21 05:37:47 2023 Finished Nearest Neighbor Search
# Mon Aug 21 05:37:47 2023 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Mon Aug 21 05:37:55 2023 Finished embedding

# %%
from google.colab import files

# %%
import os

# %%
for i in os.listdir("/content"):
  if ".html" in i:
    files.download(i)

# %%
os.listdir("/content")
# Out:
# ['.config',
#  "model_umap_{'n_components': 2, 'n_neighbors': 10, 'metric': 'cosine', 'verbose': True, 'min_dist': 0.001}_hdbscan_{'min_samples': 20, 'gen_min_span_tree': True, 'prediction_data': True, 'min_cluster_size': 20}.html",
#  "model_umap_{'n_components': 2, 'n_neighbors': 2, 'metric': 'cosine', 'verbose': True, 'min_dist': 0.001}_hdbscan_{'min_samples': 60, 'gen_min_span_tree': True, 'prediction_data': True, 'min_cluster_size': 60}.html",
#  "model_umap_{'n_components': 2, 'n_neighbors': 10, 'metric': 'cosine', 'verbose': True, 'min_dist': 0.001}_hdbscan_{'min_samples': 40, 'gen_min_span_tree': True, 'prediction_data': True, 'min_cluster_size': 40}.html",
#  "model_umap_{'n_components': 2, 'n_neighbors': 30, 'metric': 'cosine', 'verbose': True, 'min_dist': 0.1}_hdbscan_{'min_samples': 40, 'gen_min_span_tree': True, 'prediction_data': True, 'min_cluster_size': 40}.html",
#  'otomtif.csv',
#  "model_umap_{'n_components': 2, 'n_neighbors': 2, 'metric': 'cosine', 'verbose': True, 'min_dist': 0.001}_hdbscan_{'min_samples': 20, 'gen_min_span_tree': True, 'prediction_data': True, 'min_cluster_size': 20}.html",
#  "model_umap_{'n_components': 2, 'n_neighbors': 2, 'metric': 'cosine', 'verbose': True, 'min_dist': 0.001}_hdbscan_{'min_samples': 40, 'gen_min_span_tree': True, 'prediction_data': True, 'min_cluster_size': 40}.html",
#  "model_umap_{'n_components': 2, 'n_neighbors': 30, 'metric': 'cosine', 'verbose': True, 'min_dist': 0.1}_hdbscan_{'min_samples': 20, 'gen_min_span_tree': True, 'prediction_data': True, 'min_cluster_size': 20}.html",
#  'keamanan.csv',
#  "model_umap_{'n_components': 2, 'n_neighbors': 20, 'metric': 'cosine', 'verbose': True, 'min_dist': 0.01}_hdbscan_{'min_samples': 40, 'gen_min_span_tree': True, 'prediction_data': True, 'min_cluster_size': 40}.html",
#  "model_umap_{'n_components': 2, 'n_neighbors': 20, 'metric': 'cosine', 'verbose': True, 'min_dist': 0.01}_hdbscan_{'min_samples': 60, 'gen_min_span_tree': True, 'prediction_data': True, 'min_cluster_size': 60}.html",
#  'news-20230807-142456.csv',
#  'teknolog.csv',
#  'politik.csv',
#  'hiburan.csv',
#  'ekonomi.csv',
#  "model_umap_{'n_components': 2, 'n_neighbors': 2, 'metric': 'cosine', 'verbose': True, 'min_dist': 0.001}_hdbscan_{'min_samples': 5, 'gen_min_span_tree': True, 'prediction_data': True, 'min_cluster_size': 5}.html",
#  "model_umap_{'n_components': 2, 'n_neighbors': 30, 'metric': 'cosine', 'verbose': True, 'min_dist': 0.1}_hdbscan_{'min_samples': 5, 'gen_min_span_tree': True, 'prediction_data': True, 'min_cluster_size': 5}.html",
#  "model_umap_{'n_components': 2, 'n_neighbors': 10, 'metric': 'cosine', 'verbose': True, 'min_dist': 0.001}_hdbscan_{'min_samples': 60, 'gen_min_span_tree': True, 'prediction_data': True, 'min_cluster_size': 60}.html",
#  "model_umap_{'n_components': 2, 'n_neighbors': 10, 'metric': 'cosine', 'verbose': True, 'min_dist': 0.001}_hdbscan_{'min_samples': 5, 'gen_min_span_tree': True, 'prediction_data': True, 'min_cluster_size': 5}.html",
#  "model_umap_{'n_components': 2, 'n_neighbors': 20, 'metric': 'cosine', 'verbose': True, 'min_dist': 0.01}_hdbscan_{'min_samples': 20, 'gen_min_span_tree': True, 'prediction_data': True, 'min_cluster_size': 20}.html",
#  'internasional.csv',
#  "model_umap_{'n_components': 2, 'n_neighbors': 20, 'metric': 'cosine', 'verbose': True, 'min_dist': 0.01}_hdbscan_{'min_samples': 5, 'gen_min_span_tree': True, 'prediction_data': True, 'min_cluster_size': 5}.html",
#  'olahraga.csv',
#  'hukumKriminal.csv',
#  'gayaHidup.csv',
#  "model_umap_{'n_components': 2, 'n_neighbors': 30, 'metric': 'cosine', 'verbose': True, 'min_dist': 0.1}_hdbscan_{'min_samples': 60, 'gen_min_span_tree': True, 'prediction_data': True, 'min_cluster_size': 60}.html",
#  'sample_data']

# %%
hdbscan_model = hdbscan(min_samples=5, gen_min_span_tree=True, prediction_data=False, min_cluster_size=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-f2ec59bbd165> in <cell line: 1>()
# ----> 1 hdbscan_model = hdbscan(min_samples=5, gen_min_span_tree=True, prediction_data=False, min_cluster_size=5)
#
# TypeError: 'list' object is not callable

# %% [markdown]
# # BluePring

# %%
pretrained_name = "w11wo/indonesian-roberta-base-posp-tagger"

POS_indo = pipeline(
    "token-classification",
    model=pretrained_name,
    tokenizer=pretrained_name
)

# nlp("Budi sedang pergi ke pasar.")
# !pip install spacy
# !python -m spacy download id_core_news_sm
# embedding_model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
embedding_model = SentenceTransformer('firqaaa/indo-sentence-bert-base')
# embeddings = embedding_model.encode(sentences)
# print(embeddings)

umap_model = umap.UMAP(n_components=3, n_neighbors=30, metric="cosine", verbose = True)

hdbscan_model = hdbscan.HDBSCAN(min_samples=5, gen_min_span_tree=True, prediction_data=False, min_cluster_size=5)

vectorizer_model = CountVectorizer(stop_words=stopwords.words('indonesian')+["all", "halaman", "off"] + stopwords.words('english'), ngram_range=(1, 1), min_df=5)
# import openai
# from bertopic.representation import OpenAI
# # Summarization with ChatGPT
# summarization_prompt = """
# Saya memiliki topik yang dijelaskan oleh kata kunci berikut: [KEYWORDS]
# Dalam topik ini, dokumen-dokumen berikut adalah sebagian kecil namun representatif dari semua dokumen dalam topik:
# [DOCUMENTS]

# Berdasarkan informasi di atas, berikan deskripsi tentang topik ini dalam format berikut:
# topic: <description>
# """
# summarization_model = OpenAI(model="gpt-3.5-turbo", chat=True, prompt=summarization_prompt, nr_docs=5, exponential_backoff=True, diversity=0.1)


# import openai

# response = openai.Completion.create(
#   model="text-davinci-003",
#   prompt="Berikan saya topik dari kata [sekolah, belajar, siswa, merdeka]"
# )

# Representation models
# openai.api_key = "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"
representation_models = {
    "POS": POS_indo,
    "KeyBERTInspired": KeyBERTInspired(),
    "MMR": MaximalMarginalRelevance(diversity=0.3),
    "KeyBERT + MMR": [KeyBERTInspired(), MaximalMarginalRelevance(diversity=0.3)],
    # "OpenAI_Label": OpenAI(model="gpt-3.5-turbo", exponential_backoff=True, chat=True, diversity=0.1),
    # "OpenAI_Summary": [KeyBERTInspired(), summarization_model],
}

# docs
# Fit BERTopic
topic_model= BERTopic(
        embedding_model=embedding_model,
        umap_model=umap_model,
        hdbscan_model=hdbscan_model,
        vectorizer_model=vectorizer_model,
        representation_model=representation_models,
        # verbose=True
)

# %%
topics, probs = topic_model.fit_transform(doc, y=y_train)
# Out:
# UMAP(angular_rp_forest=True, metric='cosine', n_components=3, n_neighbors=30, verbose=True)
# Thu Aug 10 09:28:47 2023 Construct fuzzy simplicial set
# Thu Aug 10 09:29:08 2023 Finding Nearest Neighbors
# Thu Aug 10 09:29:09 2023 Finished Nearest Neighbor Search
# Thu Aug 10 09:29:09 2023 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Thu Aug 10 09:29:18 2023 Finished embedding

# %%
# topic_model.get_document_info(doc)[['Document', 'Name']]

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                               Name  \
# 0       -1    618              -1_kpk_ri_viral_motor
# 1        0    400               0_jokowi_dpr_budi_uu
# 2        1    399  1_juli_rekomendasi_beber_penonton
# 3        2    382     2_keamanan_petugas_jaga_sistem
# 4        3    191               3_ahli_foto_el_pakar
# ..     ...    ...                                ...
# 96      95      5            95_bank_bi_tumbuh_versi
# 97      96      5       96_luhut_macet_era_pengusaha
# 98      97      5          97_emas_pt_dalami_periksa
# 99      98      5            98_sepak_bola_batu_uang
# 100     99      5           99_inter_messi_reuni_bak
#
#                                         Representation  \
# 0    [kpk, ri, viral, motor, luhut, barcelona, harg...
# 1    [jokowi, dpr, budi, uu, kesehatan, ketua, dki,...
# 2    [juli, rekomendasi, beber, penonton, meninggal...
# 3    [keamanan, petugas, jaga, sistem, data, jamin,...
# 4    [ahli, foto, el, pakar, ekstrem, video, simak,...
# ..                                                 ...
# 96   [bank, bi, tumbuh, versi, dolar, dukung, perse...
# 97   [luhut, macet, era, pengusaha, global, dolar, ...
# 98   [emas, pt, dalami, periksa, kali, bayar, korup...
# 99   [sepak, bola, batu, uang, mata, panas, tim, fo...
# 100  [inter, messi, reuni, bak, aneh, lihat, cup, h...
#
#                                        KeyBERTInspired  \
# 0    [timnas, streaming, barcelona, live, liga, int...
# 1    [jokowi, dpr, pemilu, presiden, menkominfo, re...
# 2    [rilis, cerita, agustus, korea, kisah, rumor, ...
# 3    [keamanan, ancaman, terancam, aman, militer, p...
# 4    [agustus, penyebab, juli, peneliti, papua, efe...
# ..                                                 ...
# 96   [bank, dolar, bi, persen, indonesia, dukung, r...
# 97   [jokowi, luhut, umkm, indonesia, dolar, global...
# 98   [kpk, korupsi, pt, bayar, periksa, kali, alasa...
# 99   [foto, al, batu, sepak, uang, tim, mata, bola,...
# 100  [messi, barcelona, menang, inter, reuni, gagal...
#
#                                                    MMR  \
# 0    [kpk, ri, viral, motor, luhut, barcelona, harg...
# 1    [jokowi, dpr, budi, uu, kesehatan, ketua, dki,...
# 2    [juli, rekomendasi, beber, penonton, meninggal...
# 3    [keamanan, petugas, jaga, sistem, data, jamin,...
# 4    [ahli, foto, el, pakar, ekstrem, video, simak,...
# ..                                                 ...
# 96   [bank, bi, tumbuh, versi, dolar, dukung, perse...
# 97   [luhut, macet, era, pengusaha, global, dolar, ...
# 98   [emas, pt, dalami, periksa, kali, bayar, korup...
# 99   [sepak, bola, batu, uang, mata, panas, tim, fo...
# 100  [inter, messi, reuni, bak, aneh, lihat, cup, h...
#
#                                          KeyBERT + MMR  \
# 0    [timnas, streaming, barcelona, live, liga, int...
# 1    [jokowi, dpr, pemilu, presiden, menkominfo, re...
# 2    [rilis, cerita, agustus, korea, kisah, rumor, ...
# 3    [keamanan, ancaman, terancam, aman, militer, p...
# 4    [agustus, penyebab, juli, peneliti, papua, efe...
# ..                                                 ...
# 96   [bank, dolar, bi, persen, indonesia, dukung, r...
# 97   [jokowi, luhut, umkm, indonesia, dolar, global...
# 98   [kpk, korupsi, pt, bayar, periksa, kali, alasa...
# 99   [foto, al, batu, sepak, uang, tim, mata, bola,...
# 100  [messi, barcelona, menang, inter, reuni, gagal...
#
#                                    Representative_Docs
# 0    [link live streaming persib vs bali united di ...
# 1    [bentrok pildun dan coldplay di jokowi mulai l...
# 2    [sinopsis zombieland double bioskop trans tv j...
# 3    [keamanan lesti kejora terus dipantau, sosiolo...
# 4    [ahli jelaskan sisi gempa buat kehidupan laut,...
# ..                                                 ...
# 96   [dukung laju bank mandiri kucurkan kredit tril...
# 97   [ojk buka suara soal penghapusan kredit macet ...
# 98   [rafael alun ungkap alasan tolak bayar restitu...
# 99   [foto menikmati keagungan piramida giza saat m...
# 100  [messi cetak inter miami menang lagi di league...
#
# [101 rows x 8 columns]

# %%
topic_model.visualize_barchart(top_n_topics=30)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f238e080-b356-426d-8c2b-4a4061558511" class="plotly-graph-div" style="height:2000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f238e080-b356-426d-8c2b-4a4061558511")) {                    Plotly.newPlot(                        "f238e080-b356-426d-8c2b-4a4061558511",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.028676616108419907,0.031251890662773056,0.033447261921978985,0.03804276704862123,0.05417529291117949],"y":["kesehatan  ","uu  ","budi  ","dpr  ","jokowi  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.028346147467342247,0.028346147467342247,0.030826518540449578,0.03149571940815805,0.0494375154755074],"y":["meninggal  ","penonton  ","beber  ","rekomendasi  ","juli  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.019154585373748485,0.022210114231236124,0.022284116890763213,0.022760418544959974,0.07656028964989325],"y":["data  ","sistem  ","jaga  ","petugas  ","keamanan  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.038987918350403106,0.045401345889979364,0.047234542165994035,0.04891628258914604,0.05079472142686707],"y":["ekstrem  ","pakar  ","el  ","foto  ","ahli  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.0529955621424862,0.054829834867587565,0.05559826443690642,0.07603210086910954,0.09034366706109422],"y":["tips  ","bikin  ","cegah  ","dokter  ","makanan  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.03587695421289166,0.03826811503219203,0.06523095138638615,0.07111839686478716,0.10953880314548359],"y":["harga  ","murah  ","listrik  ","produksi  ","mobil  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.0740767574033838,0.08815465995171966,0.09130438969215972,0.09130438969215972,0.11714308768102387],"y":["markas  ","berubah  ","dirilis  ","akun  ","elon  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.07055629122792824,0.07248867020856532,0.08944921958911915,0.09155561072315237,0.12595152528322973],"y":["wakil  ","perempat  ","jonatan  ","final  ","open  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.06019853116941504,0.06589823220513495,0.06655981292298824,0.07001757692174419,0.10771085805459346],"y":["ditangkap  ","tersangka  ","pria  ","diduga  ","polisi  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.05645818216612203,0.06843641052459364,0.07984247894535924,0.08681576520578414,0.1231312553143325],"y":["link  ","milan  ","onana  ","mu  ","madrid  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.055042353607384416,0.06374046567267909,0.07429932605356826,0.09618830114642764,0.11759713065653171],"y":["juta  ","hidup  ","nama  ","polisi  ","nomor  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.041726599945223534,0.04619090631764003,0.08226382072455853,0.08289208027481615,0.08803700195361476],"y":["juara  ","filipina  ","league  ","thailand  ","sea  "],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.041559693545442644,0.04600614269236947,0.07910942870229269,0.08256051195371689,0.08502773715956392],"y":["vietnam  ","filipina  ","league  ","thailand  ","sea  "],"type":"bar","xaxis":"x13","yaxis":"y13"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.0921597409702914,0.09744987745990123,0.11868091062493487,0.15083352302092226,0.164 ...

# %%
for i in encoder.classes_:
  print("{} : {}".format(i, encoder.transform([i])[0]))
# Out:
# Ekonomi : 0
# GayaHidup : 1
# Hiburan : 2
# HukumKrimnial : 3
# Internasional : 4
# Keamanan : 5
# Olahraga : 6
# Otomotif : 7
# Politik : 8
# Teknologi : 9

# %%
topic_model.get_topic(3)
# Out:
# [('ahli', 0.05079472142686707),
#  ('foto', 0.04891628258914604),
#  ('el', 0.047234542165994035),
#  ('pakar', 0.045401345889979364),
#  ('ekstrem', 0.038987918350403106),
#  ('video', 0.033574855549808866),
#  ('simak', 0.03341821572891695),
#  ('potensi', 0.029808197811263905),
#  ('panas', 0.029791245181363616),
#  ('kepala', 0.02849220813781123)]

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ace00c94-8531-4e90-9f73-db3b6e450df8" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ace00c94-8531-4e90-9f73-db3b6e450df8")) {                    Plotly.newPlot(                        "ace00c94-8531-4e90-9f73-db3b6e450df8",                        [{"customdata":[[0,"jokowi | dpr | budi | uu | kesehatan",400],[1,"juli | rekomendasi | beber | penonton | meninggal",399],[2,"keamanan | petugas | jaga | sistem | data",382],[3,"ahli | foto | el | pakar | ekstrem",191],[4,"makanan | dokter | cegah | bikin | tips",144],[5,"mobil | produksi | listrik | murah | harga",136],[6,"elon | akun | dirilis | berubah | markas",52],[7,"open | final | jonatan | perempat | wakil",51],[8,"polisi | diduga | pria | tersangka | ditangkap",49],[9,"madrid | mu | onana | milan | link",47],[10,"nomor | polisi | nama | hidup | juta",45],[11,"sea | thailand | league | filipina | juara",45],[12,"sea | thailand | league | filipina | vietnam",45],[13,"agama | gugatan | hadir | pemeriksaan | sidang",41],[14,"cepat | bangun | tol | ikn | proyek",41],[15,"bbm | motor | listrik | juta | harga",40],[16,"aplikasi | fitur | gabung | nasib | habis",38],[17,"piala | kualifikasi | dunia | seri | vietnam",37],[18,"terbaik | dunia | bali | paspor | rekomendasi",37],[19,"laporan | dugaan | jokowi | polda | laporkan",36],[20,"foto | manusia | jepang | pria | wanita",36],[21,"persija | liga | united | pemain | lawan",35],[22,"ubah | ajak | bbm | pakar | air",32],[23,"keluarga | polri | ilegal | sakit | keras",30],[24,"sesuai | bahasa | daging | sambut | sejarah",29],[25,"open | final | perempat | wakil | siaran",29],[26,"tersangka | kpk | suap | tni | basarnas",27],[27,"tni | basarnas | militer | kpk | penetapan",27],[28,"persija | liga | pemain | lawan | united",27],[29,"timnas | putri | sea | league | pemain",23],[30,"ekspor | larang | produk | eropa | setop",23],[31,"onana | mu | imbang | madrid | ditahan",21],[32,"data | paspor | pakar | diduga | kominfo",21],[33,"putri | timnas | league | sea | pemain",21],[34,"menkominfo | budi | bts | ancam | janji",21],[35,"pengusaha | jokowi | china | turun | kali",19],[36,"belanja | live | pindah | jutaan | bayar",19],[37,"kg | pertamina | dirut | stok | aman",19],[38,"erick | thohir | pertamina | bumn | bos",18],[39,"singgung | semester | ri | ekonomi | negara",18],[40,"bangkit | posisi | rapor | pekan | asing",18],[41,"picu | jatuh | hubungan | mudah | ganggu",17],[42,"versi | mudah | daging | raksasa | meter",17],[43,"bunga | dolar | bi | imbas | data",17],[44,"motor | kunci | anti | honda | aman",17],[45,"tua | foto | terancam | panas | kamera",17],[46,"mobil | tol | pakai | viral | hindari",16],[47,"australia | open | hasil | susah | lolos",16],[48,"ronaldo | arab | gol | al | saudi",16],[49,"australia | open | hasil | susah | lolos",16],[50,"milan | madrid | gol | benzema | bungkam",16],[51,"bumn | lapor | mata | utama | air",16],[52,"pimpinan | basarnas | kpk | mundur | ott",15],[53,"dirilis | diklaim | intip | resmi | mengintip",15],[54,"liverpool | klopp | reaksi | menit | dortmund",15],[55,"thohir | erick | absen | sejarah | pssi",14],[56,"korupsi | dana | selatan | dugaan | terkait",14],[57,"pertamina | surabaya | bbm | dijual | dki",13],[58,"rumah | kisah | pos | air | viral",13],[59,"ronaldo | arab | al | saudi | gol",13],[60,"kualifikasi | piala | wanita | dunia | vietnam",12],[61,"fifa | rumput | stadion | kunjungan | kamar",11],[62,"bts | kominfo | hakim | dirut | proyek",11],[63,"link | streaming | madrid | live | vs",11],[64,"merah | ai | jakarta | lokasi | ditutup",11],[65,"liverpool | klopp | batal | gol | reuni",11],[66,"pesawat | penumpang | kursi | api | tertinggal",11],[67,"fifa | rumput | stadion | kunjungan | ka ...
